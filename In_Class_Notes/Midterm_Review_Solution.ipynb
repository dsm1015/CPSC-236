# %% [markdown]
# # CPSC 236 Midterm Review Problems

# %% [markdown]
# ## Review Problem 1
#
# Create an ATM machine that manages a users balance.
#
# ### Console
# ```powershell
# Simple ATM System
#
# Choose an option:
# 1. Check Balance
# 2. Withdraw Money
# 3. Exit
#
# Enter choice: 1
# Your current balance is $1000
#
# Choose an option:
# 1. Check Balance
# 2. Withdraw Money
# 3. Exit
#
# Enter choice: 2
# Enter amount to withdraw: 150
# Transaction successful. Your new balance is $850.
#
# Choose an option:
# 1. Check Balance
# 2. Withdraw Money
# 3. Exit
#
# Enter choice: 3
# Goodbye!
# ```
#
# ### Specifications
# - The user should be able to check their balance and withdraw money.
# - The user should have an initial balance of $1000
# - Use a loop to allow the user to continue performing operations until they exit
# - Validate user inputs and use functions to organize the code

# %%
def check_balance(balance):
    print("Balance: $", balance[0])
    return
    
def withdraw(amount, balance):
    if amount > balance[0]:
        print("Cannot withdraw more than balance!")
        return
    elif amount < 0:
        print("Invalid withdraw amount.")
        return 
    else:
        balance[0] = balance[0] - amount
    return

def main():
    balance = [1000]
    option = 1
    while True:
        print("Choose an option:")
        print("1. Check Balance")
        print("2. Withdraw Money")
        print("3. Exit")
        option = int(input("Enter Choice: "))
        print()
        
        if option == 1:
            check_balance(balance)
        elif option == 2:
            amount = float(input("Withdraw Amount: "))
            withdraw(amount, balance)
        elif option == 3:
            break
        else:
            print("Please enter a valid option.")
        print()
            
if __name__ == "__main__":
    main()
# Out:
# Choose an option:
# 1. Check Balance
# 2. Withdraw Money
# 3. Exit
# Enter Choice: 1
#
# Balance: $ 1000
#
# Choose an option:
# 1. Check Balance
# 2. Withdraw Money
# 3. Exit
# Enter Choice: 2
#
# Withdraw Amount: 300
#
# Choose an option:
# 1. Check Balance
# 2. Withdraw Money
# 3. Exit
# Enter Choice: 1
#
# Balance: $ 700.0
#
# Choose an option:
# 1. Check Balance
# 2. Withdraw Money
# 3. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7360\662994282.py in <module>
#      37
#      38 if __name__ == "__main__":
# ---> 39     main()
#      40
#
# ~\AppData\Local\Temp\ipykernel_7360\662994282.py in main()
#      22         print("2. Withdraw Money")
#      23         print("3. Exit")
# ---> 24         option = int(input("Enter Choice: "))
#      25         print()
#      26
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Review Problem 2
#
# Create a module named `currency_converter.py` define a fuction to convert the currency from USD to EUR.
#
# ### Console
# ```powershell
# Currency Converter
#
# Enter an amount in USD: 123.43
# $123.43 in EUR: 113.56
#
# Continue (y/n)? y
#
# Enter an amount in USD: 22
# $123.43 in EUR: 20.24
#
# Continue (y/n)? n
#
# Goodbye!
# ```
#
# ### Specifications
# - The program should import the module `currency_converter`
# - You can find the USD to EUR conversion rate online or use:
# `1 USD = 0.92 EUR`
# - Make sure to store the conversion rate in constant
# - Ensure the user inputs a valid amount

# %%
import currency_converter as cc

def main():
    
    option = 'y'
    
    while option.lower() == 'y':
        
        amount = float(input("Enter an amount in USD: "))
        eur_amount = cc.usd_to_eur(amount)
        print("$"+str(amount) + " in EUR: " + str(eur_amount))
        print()
        
        option = input("Continue (y/n)?")
        
        if option == 'n':
            print("Goodbye!")
    
if __name__ == "__main__":
    main()
# Out:
# Enter an amount in USD: 24
# $24.0 in EUR: 22.08
#
# Continue (y/n)?y
# Enter an amount in USD: 123.43
# $123.43 in EUR: 113.56
#
# Continue (y/n)?n
# Goodbye!

# %% [markdown]
# ## Review Problem 3
#
# Create a simple Python program that allows users to manage a list of their favorite foods.
#
# ### Console
# ```powershell
# Favorite Foods Tracker
#
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
#
# Enter choice: 1
# Your favorite foods are: []
#
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
#
# Enter choice: 2
# Enter a food to add: Pizza
# Pizza added to your favorite foods.
#
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
#
# Enter choice: 1
# Your favorite foods are: [Pizza]
#
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
#
# Enter choice: 3
# Enter a food to remove: Pizza
# Pizza removed from your favorite foods.
#
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
#
# Enter choice: 4
# Goodbye!
# ```
#
# ### Specifications
# - The user should be able to view their list of favorite foods, add a new food to the list and remove a food from the list.
# - Start with an empty list of favorite foods.
# - Use a loop to allow the user to continue performing operations until they choose to exit.
# - Validate user inputs where necessary (e.g., check that a food to be removed is actually in the list).

# %%
def show_foods(fav_foods):
    print(fav_foods)
    
def add_food(fav_foods):
    add = input("Enter a food to add: ")
    fav_foods.append(add)
    
def remove_food(fav_foods):
    toremove = input("Enter a food to remove: ")
    if toremove in fav_foods:
        fav_foods.remove(toremove)
    else:
        print("item not in list")

def main():
    fav_foods = []
    
    while True:
        print("Choose an option:")
        print("1. Show Favorite Foods")
        print("2. Add a Favorite Food")
        print("3. Remove a Favorite Food")
        print("4. Exit")
        option = int(input("Enter Choice: "))
        print()
        
        if option == 1:
            show_foods(fav_foods)
        elif option == 2:
            add_food(fav_foods)
        elif option == 3:
            remove_food(fav_foods)
        elif option == 4:
            break;
        else:
            print("invalid choice!")
    
    
if __name__ == "__main__":
    main()
# Out:
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
# Enter Choice: 1
#
# []
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
# Enter Choice: 2
#
# Enter a food to add: pizza
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
# Enter Choice: 1
#
# ['pizza']
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
# Enter Choice: 3
#
# Enter a food to remove: pizza
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
# Enter Choice: 1
#
# []
# Choose an option:
# 1. Show Favorite Foods
# 2. Add a Favorite Food
# 3. Remove a Favorite Food
# 4. Exit
# Enter Choice: 4
